# %% [markdown]
# <a href="https://colab.research.google.com/github/Lee-9909/test_project/blob/main/%5B20263353_%EC%9D%B4%EC%A7%80%EC%88%98_%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "이지수"
age = 26

print("=====", "자기소개", "=====", sep=" ")

print("이름 : ", end="")
print(name)

print("학과 : 정보통신공학과")
print("관심 분야 : 네트워크, 보안")

print()

print(f"안녕하세요. 저는 {name}이고 {age}살입니다.")
print("네트워크와 보안 분야를 열심히 공부하고 있습니다.\n잘 부탁드립니다!")
# Out:
# ===== 자기소개 =====
# 이름 : 이지수
# 학과 : 정보통신공학과
# 관심 분야 : 네트워크, 보안
#
# 안녕하세요. 저는 이지수이고 26살입니다.
# 네트워크와 보안 분야를 열심히 공부하고 있습니다.
# 잘 부탁드립니다!
